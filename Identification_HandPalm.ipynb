# %% [markdown]
# <a href="https://colab.research.google.com/github/NHoangThanh/AI-assignment/blob/main/Identification_HandPalm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray, save
from keras.utils import load_img, img_to_array

folder = 'drive/MyDrive/Handpalm_train/'
photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('Mot'):
    output = 1.0
  if file.startswith('Hai'):
    output = 2.0
  if file.startswith('Ba'):
    output = 3.0
  if file.startswith('Bon'):
    output = 4.0
  if file.startswith('Nam'):
    output = 5.0
  if file.startswith('Sau'):
    output = 6.0
  if file.startswith('Bay'):
    output = 7.0
  if file.startswith('Tam'):
    output = 8.0
  if file.startswith('Chin'):
    output = 9.0
  if file.startswith('Muoi'):
    output = 10.0
  if file.startswith('MuoiMot'):
    output = 11.0
  if file.startswith('MuoiHai'):
    output = 12.0
  if file.startswith('MuoiBa'):
    output = 13.0
  if file.startswith('MuoiBon'):
    output = 14.0
  if file.startswith('MuoiNam'):
    output = 15.0
  if file.startswith('MuoiSau'):
    output = 16.0
  if file.startswith('MuoiBay'):
    output = 17.0
  if file.startswith('MuoiTam'):
    output = 18.0
  if file.startswith('MuoiChin'):
    output = 19.0
  if file.startswith('HaiMuoi'):
    output = 20.0
  photo = load_img(folder + file, target_size =(100,100))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)

photos_train = asarray(photos)
labels_train = asarray(labels)
print(photos_train.shape, labels_train.shape)
# Out:
# (600, 100, 100, 3) (600,)

# %%
folder = 'drive/MyDrive/Handpalm_test/'
photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('Mot'):
    output = 1.0
  if file.startswith('Hai'):
    output = 2.0
  if file.startswith('Ba'):
    output = 3.0
  if file.startswith('Bon'):
    output = 4.0
  if file.startswith('Nam'):
    output = 5.0
  if file.startswith('Sau'):
    output = 6.0
  if file.startswith('Bay'):
    output = 7.0
  if file.startswith('Tam'):
    output = 8.0
  if file.startswith('Chin'):
    output = 9.0
  if file.startswith('Muoi'):
    output = 10.0
  if file.startswith('MuoiMot'):
    output = 11.0
  if file.startswith('MuoiHai'):
    output = 12.0
  if file.startswith('MuoiBa'):
    output = 13.0
  if file.startswith('MuoiBon'):
    output = 14.0
  if file.startswith('MuoiNam'):
    output = 15.0
  if file.startswith('MuoiSau'):
    output = 16.0
  if file.startswith('MuoiBay'):
    output = 17.0
  if file.startswith('MuoiTam'):
    output = 18.0
  if file.startswith('MuoiChin'):
    output = 19.0
  if file.startswith('HaiMuoi'):
    output = 20.0
  photo = load_img(folder + file, target_size =(100,100))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)

photos_test = asarray(photos)
labels_test = asarray(labels)
print(photos_test.shape, labels_test.shape)
# Out:
# (200, 100, 100, 3) (200,)

# %%
photos_train = photos_train.reshape(600, 100, 100, 3)
photos_train = photos_train.astype('float32')/255 
photos_test = photos_test.reshape(200, 100, 100, 3)
photos_test = photos_test.astype('float32')/255



from keras.utils import  to_categorical
labels_train = to_categorical(labels_train)
labels_test = to_categorical(labels_test)
photos_train.shape, labels_train.shape, photos_test.shape, labels_test.shape
# Out:
# ((600, 100, 100, 3), (600, 21), (200, 100, 100, 3), (200, 21))

# %%
fine_labels = [
    'Mot',  # id 0
    'Hai',
    'Ba',
    'Bon',
    'Nam',
    'Sau',
    'Bay',
    'Tam',
    'Chin',
    'Muoi',
    'MuoiMot',
    'MuoiHai',
    'MuoiBa',
    'MuoiBon',
    'MuoiNam',
    'MuoiSau',
    'MuoiBay',
    'MuoiTam',
    'MuoiChin',
    'HaiMuoi',
]

# Name the numeric classes by using text file
class_names = {}
counter = 0       # For indexing keys

# Add keys and references
for instances in fine_labels:
  class_names.update({counter: instances})   # Add to dictionary
  counter+=1    # Update counter

# %%
from random import randint
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# Display multiple images
fig_display = plt.figure(figsize=[10, 10])
chosen_idx = randint(0, 600)

# Scan image in array
for indx in range(chosen_idx, chosen_idx+20, 1):
  axes = fig_display.add_subplot(4, 5, indx - chosen_idx +1)
  axes.imshow(photos_train[indx, :, :])
  axes.set_xticks([ ])
  axes.set_yticks([ ])
  axes.set_title("Class: {}".format(class_names[labels_train[indx,0]]))

# %%
from keras.models import Sequential, Model
from keras import Input, Model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers import BatchNormalization, LeakyReLU
batch_size = 64
epochs = 30
classes = 21

model = Sequential()
#CNN
model.add(Conv2D(32, kernel_size = (3,3), activation = 'linear',
                 input_shape = (100,100,3), padding = 'same')) 
# nhan tich chap 32 lan
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(64, (3,3), activation = 'linear', padding ='same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(128, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))
#ANN
model.add(Flatten())
model.add(Dense(128, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation ='softmax'))

# %%
#compile
model.compile(optimizer = Adam(), loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])
model.summary()

train = model.fit(photos_train, labels_train, batch_size = batch_size , 
                  epochs = epochs, verbose = 1)

test_loss, test_acc = model.evaluate(photos_test, labels_test)
print('do chinh xac', test_acc)
print('ham mat mat', test_loss)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 100, 100, 32)      896
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 100, 100, 32)      0
#
#  max_pooling2d_3 (MaxPooling  (None, 50, 50, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 50, 50, 64)        18496
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 50, 50, 64)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 128)       73856
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_5 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 21632)             0
#
#  dense_2 (Dense)             (None, 128)               2769024
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 128)               0
#
#  dense_3 (Dense)             (None, 21)                2709
#
# =================================================================
# Total params: 2,864,981
# Trainable params: 2,864,981
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 10/10 [==============================] - 1s 31ms/step - loss: 3.0332 - accuracy: 0.1183
# Epoch 2/30
# 10/10 [==============================] - 0s 25ms/step - loss: 2.1358 - accuracy: 0.4617
# Epoch 3/30
# 10/10 [==============================] - 0s 26ms/step - loss: 0.9169 - accuracy: 0.7617
# Epoch 4/30
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3297 - accuracy: 0.9033
# Epoch 5/30
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1234 - accuracy: 0.9667
# Epoch 6/30
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0771 - accuracy: 0.9800
# Epoch 7/30
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0481 - accuracy: 0.9850
# Epoch 8/30
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0208 - accuracy: 0.9933
# Epoch 9/30
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0108 - accuracy: 0.9950
# Epoch 10/30
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 11/30
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 12/30
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 13/30
# 10/10 [==============================] - 0s 25ms/step - loss: 7.5925e-04 - accuracy: 1.0000
# Epoch 14/30
# 10/10 [==============================] - 0s 24ms/step - loss: 3.9963e-04 - accuracy: 1.0000
# Epoch 15/30
# 10/10 [==============================] - 0s 26ms/step - loss: 2.7498e-04 - accuracy: 1.0000
# Epoch 16/30
# 10/10 [==============================] - 0s 25ms/step - loss: 2.0932e-04 - accuracy: 1.0000
# Epoch 17/30
# 10/10 [==============================] - 0s 25ms/step - loss: 1.7021e-04 - accuracy: 1.0000
# Epoch 18/30
# 10/10 [==============================] - 0s 25ms/step - loss: 1.4717e-04 - accuracy: 1.0000
# Epoch 19/30
# 10/10 [==============================] - 0s 25ms/step - loss: 1.3410e-04 - accuracy: 1.0000
# Epoch 20/30
# 10/10 [==============================] - 0s 24ms/step - loss: 1.2257e-04 - accuracy: 1.0000
# Epoch 21/30
# 10/10 [==============================] - 0s 25ms/step - loss: 1.1378e-04 - accuracy: 1.0000
# Epoch 22/30
# 10/10 [==============================] - 0s 25ms/step - loss: 1.0646e-04 - accuracy: 1.0000
# Epoch 23/30
# 10/10 [==============================] - 0s 24ms/step - loss: 9.9599e-05 - accuracy: 1.0000
# Epoch 24/30
# 10/10 [==============================] - 0s 25ms/step - loss: 9.3673e-05 - accuracy: 1.0000
# Epoch 25/30
# 10/10 [==============================] - 0s 25ms/step - loss: 8.8687e-05 - accuracy: 1.0000
# Epoch 26/30
# 10/10 [==============================] - 0s 24ms/step - loss: 8.3897e-05 - accuracy: 1.0000
# Epoch 27/30
# 10/10 [==============================] - 0s 25ms/step - loss: 7.9789e-05 - accuracy: 1.0000
# Epoch 28/30
# 10/10 [==============================] - 0s 25ms/step - loss: 7.5798e-05 - accuracy: 1.0000
# Epoch 29/30
# 10/10 [==============================] - 0s 25ms/step - loss: 7.2249e-05 - accuracy: 1.0000
# Epoch 30/30
# 10/10 [==============================] - 0s 24ms/step - loss: 6.8807e-05 - accuracy: 1.0000
# 7/7 [==============================] - 0s 12ms/step - loss: 1.5769 - accuracy: 0.8000
# do chinh xac 0.800000011920929
# ham mat mat 1.5768632888793945

# %%
accuracy = train.history['accuracy']
loss = train.history['loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'k', label = 'Train accuracy')
plt.plot(epochs, loss, 'b', label = 'Train loss')
plt.legend(['Train accuracy', 'Train loss'])
plt.show()

# %%
model.save('drive/MyDrive/modelHandPalm.h5')

# %%
class_HandPalm = {1: 'HandPalm-1',2: 'HandPalm-2',3: 'HandPalm-3',
                  4: 'HandPalm-4',5: 'HandPalm-5',6: 'HandPalm-6',
                  7: 'HandPalm-7',8: 'HandPalm-8',9: 'HandPalm-9',
                  10: 'HandPalm-10',11: 'HandPalm-11',12: 'HandPalm-12',
                  13: 'HandPalm-13',14: 'HandPalm-14',15: 'HandPalm-15',
                  16: 'HandPalm-16',17: 'HandPalm-17',18: 'HandPalm-18',
                  19: 'HandPalm-19',20: 'HandPalm-20'}

# %%
#test
filePath = 'drive/MyDrive/Handpalm_test/Ba31.JPG'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(100,100))
arrayImage = img_to_array(testImage).reshape(1,100,100,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_HandPalm[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 217ms/step
# Predicted:  HandPalm-3

# %%
#test
filePath = 'drive/MyDrive/Handpalm_test/Chin31.JPG'
testImage = load_img(filePath, color_mode = 'rgb', target_size=(100,100))
arrayImage = img_to_array(testImage).reshape(1,100,100,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", class_HandPalm[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# Predicted:  HandPalm-9
