# %% [markdown]
# <a href="https://colab.research.google.com/github/NHoangThanh/AI-assignment/blob/main/FaceImageinClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray, save
from keras.utils import load_img, img_to_array

folder = 'drive/MyDrive/FaceImage_train/'
photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('dung'):
    output = 1.0
  if file.startswith('Ha'):
    output = 2.0
  if file.startswith('hakiet'):
    output = 3.0
  if file.startswith('hau'):
    output = 4.0
  if file.startswith('Hieu_'):
    output = 5.0
  if file.startswith('hoaifong_'):
    output = 6.0
  if file.startswith('Hoang'):
    output = 7.0
  if file.startswith('HQHuy'):
    output = 8.0
  if file.startswith('HuuLong'):
    output = 9.0
  if file.startswith('Loc'):
    output = 10.0
  if file.startswith('ngocThach'):
    output = 11.0
  if file.startswith('NTKiet'):
    output = 12.0
  if file.startswith('Phuc'):
    output = 13.0
  if file.startswith('pqhuy'):
    output = 14.0
  if file.startswith('QuangPhuc'):
    output = 15.0
  if file.startswith('sang'):
    output = 16.0
  if file.startswith('SonTung_'):
    output = 17.0
  if file.startswith('TanDat'):
    output = 18.0
  if file.startswith('Thai'):
    output = 19.0
  if file.startswith('thanh'):
    output = 20.0
  if file.startswith('Thao'):
    output = 21.0
  if file.startswith('Thinh'):
    output = 22.0
  if file.startswith('tien'):
    output = 23.0
  if file.startswith('TLoc'):
    output = 24.0
  if file.startswith('Trong'):
    output = 25.0
  if file.startswith('Van'):
    output = 26.0
  photo = load_img(folder + file, target_size =(30,40))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)

photos_train = asarray(photos)
labels_train = asarray(labels)
print(photos_train.shape, labels_train.shape)
# Out:
# (1159, 30, 40, 3) (1159,)

# %%
folder = 'drive/MyDrive/FaceImage_test/'
photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('dung'):
    output = 1.0
  if file.startswith('Ha'):
    output = 2.0
  if file.startswith('hakiet'):
    output = 3.0
  if file.startswith('hau'):
    output = 4.0
  if file.startswith('Hieu_'):
    output = 5.0
  if file.startswith('hoaifong_'):
    output = 6.0
  if file.startswith('Hoang'):
    output = 7.0
  if file.startswith('HQHuy'):
    output = 8.0
  if file.startswith('HuuLong'):
    output = 9.0
  if file.startswith('Loc'):
    output = 10.0
  if file.startswith('ngocThach'):
    output = 11.0
  if file.startswith('NTKiet'):
    output = 12.0
  if file.startswith('Phuc'):
    output = 13.0
  if file.startswith('pqhuy'):
    output = 14.0
  if file.startswith('QuangPhuc'):
    output = 15.0
  if file.startswith('sang'):
    output = 16.0
  if file.startswith('SonTung_'):
    output = 17.0
  if file.startswith('TanDat'):
    output = 18.0
  if file.startswith('Thai'):
    output = 19.0
  if file.startswith('thanh'):
    output = 20.0
  if file.startswith('Thao'):
    output = 21.0
  if file.startswith('Thinh'):
    output = 22.0
  if file.startswith('tien'):
    output = 23.0
  if file.startswith('TLoc'):
    output = 24.0
  if file.startswith('Trong'):
    output = 25.0
  if file.startswith('Van'):
    output = 26.0
  photo = load_img(folder + file, target_size =(30,40))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos_test = asarray(photos)
labels_test = asarray(labels)
print(photos_test.shape, labels_test.shape)
# Out:
# (384, 30, 40, 3) (384,)

# %%
photos_train = photos_train.reshape(1159, 30, 40, 3)
photos_train = photos_train.astype('float32')/255 
photos_test = photos_test.reshape(384, 30, 40, 3)
photos_test = photos_test.astype('float32')/255



from keras.utils import  to_categorical
labels_train = to_categorical(labels_train)
labels_test = to_categorical(labels_test)
photos_train.shape, labels_train.shape, photos_test.shape, labels_test.shape
# Out:
# ((1159, 30, 40, 3), (1159, 27), (384, 30, 40, 3), (384, 27))

# %%
fine_labels = [
    'dung',  # id 0
    'Ha',
    'hakiet',
    'hau',
    'Hieu_',
    'hoaifong_',
    'Hoang',
    'HQHuy',
    'HuuLong',
    'Loc',
    'ngocThach',
    'NTKiet',
    'Phuc',
    'pqhuy',
    'QuangPhuc',
    'sang',
    'SonTung_',
    'TanDat',
    'Thai',
    'thanh',
    'Thao',
    'Thinh',
    'tien',
    'TLoc',
    'Trong',
    'Van',
]

# Name the numeric classes by using text file
class_names = {}
counter = 0       # For indexing keys

# Add keys and references
for instances in fine_labels:
  class_names.update({counter: instances})   # Add to dictionary
  counter+=1    # Update counter

# %%
from random import randint
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# Display multiple images
fig_display = plt.figure(figsize=[10, 10])
chosen_idx = randint(0, 1159)

# Scan image in array
for indx in range(chosen_idx, chosen_idx+20, 1):
  axes = fig_display.add_subplot(4, 5, indx - chosen_idx +1)
  axes.imshow(photos_train[indx, :, :])
  axes.set_xticks([ ])
  axes.set_yticks([ ])

# %%
from keras.models import Sequential, Model
from keras import Input, Model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers import BatchNormalization, LeakyReLU
batch_size = 128
epochs = 30
classes = 27

model = Sequential()
#CNN
model.add(Conv2D(32, kernel_size = (3,3), activation = 'linear',
                 input_shape = (30,40,3), padding = 'same')) 
# nhan tich chap 32 lan
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(64, (3,3), activation = 'linear', padding ='same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(128, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

#ANN
model.add(Flatten())
model.add(Dense(128, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation ='softmax'))

# %%
#compile
model.compile(optimizer = Adam(), loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])
model.summary()

train = model.fit(photos_train, labels_train, batch_size = batch_size , 
                  epochs = epochs, verbose = 1)

test_loss, test_acc = model.evaluate(photos_test, labels_test)
print('do chinh xac', test_acc)
print('ham mat mat', test_loss)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 30, 40, 32)        896
#
#  leaky_re_lu (LeakyReLU)     (None, 30, 40, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 20, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 15, 20, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 15, 20, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 10, 64)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 10, 128)        73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 10, 128)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 5, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2560)              0
#
#  dense (Dense)               (None, 128)               327808
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 27)                3483
#
# ...

# %%
accuracy = train.history['accuracy']
loss = train.history['loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'k', label = 'Train accuracy')
plt.plot(epochs, loss, 'b', label = 'Train loss')
plt.legend(['Train accuracy', 'Train loss'])
plt.show()

# %%
model.save('drive/MyDrive/modelface.h5')

# %%
file_path = '/content/drive/MyDrive/FaceImage_test/thanh46.jpg'
test_img  = load_img(file_path, color_mode='rgb', target_size=(30, 40))
img_arr   = img_to_array(test_img).reshape(1, 30, 40, 3)/255

class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])
plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Predicted class: thanh
