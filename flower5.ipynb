# %% [markdown]
# <a href="https://colab.research.google.com/github/NHoangThanh/AI-assignment/blob/main/flower5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray, save
from keras.utils import load_img, img_to_array
folder = 'drive/MyDrive/flower_images_train/'
photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('Lilly'):
    output = 1.0
  if file.startswith('Lotus'):
    output = 2.0
  if file.startswith('Orchid'):
    output = 3.0
  if file.startswith('Sunflower'):
    output = 4.0
  if file.startswith('Tulip'):
    output = 5.0

  photo = load_img(folder + file, target_size =(128,128))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)

photos_train = asarray(photos)
labels_train = asarray(labels)
print(photos_train.shape, labels_train.shape)
# Out:
# (4000, 128, 128, 3) (4000,)

# %%
folder = 'drive/MyDrive/flower_image_test/'
photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('Lilly'):
    output = 1.0
  if file.startswith('Lotus'):
    output = 2.0
  if file.startswith('Orchid'):
    output = 3.0
  if file.startswith('Sunflower'):
    output = 4.0
  if file.startswith('Tulip'):
    output = 5.0

  photo = load_img(folder + file, target_size =(128,128))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)

photos_test = asarray(photos)
labels_test = asarray(labels)
print(photos_test.shape, labels_test.shape)
# Out:
# (999, 128, 128, 3) (999,)

# %%
photos_train = photos_train.reshape(4000, 128, 128, 3)
photos_train = photos_train.astype('float32')/255 
photos_test = photos_test.reshape(999, 128, 128, 3)
photos_test = photos_test.astype('float32')/255



from keras.utils import  to_categorical
labels_train = to_categorical(labels_train)
labels_test = to_categorical(labels_test)
photos_train.shape, labels_train.shape, photos_test.shape, labels_test.shape
# Out:
# ((4000, 128, 128, 3), (4000, 6), (999, 128, 128, 3), (999, 6))

# %%
fine_labels = [
    'Lilly',  # id 0
    'Lotus',
    'Orchid',
    'Sunflower',
    'Tulip',
]

class_names = {}
counter = 0      

for instances in fine_labels:
  class_names.update({counter: instances})   
  counter+=1

# %%
from keras.models import Sequential, Model
from keras import Input, Model
from keras.optimizers import Adam
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers import BatchNormalization, LeakyReLU
batch_size = 128
epochs = 30
classes = 6

model = Sequential()
#CNN
model.add(Conv2D(32, kernel_size = (3,3), activation = 'linear',
                 input_shape = (128,128,3), padding = 'same')) 
# nhan tich chap 32 lan
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(64, (3,3), activation = 'linear', padding ='same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(128, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

#ANN
model.add(Flatten())
model.add(Dense(128, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation ='softmax'))

# %%
#compile
model.compile(optimizer = Adam(), loss = 'categorical_crossentropy', 
              metrics = ['accuracy'])
model.summary()

train = model.fit(photos_train, labels_train, batch_size = batch_size , 
                  epochs = epochs, verbose = 1)

test_loss, test_acc = model.evaluate(photos_test, labels_test)
print('do chinh xac', test_acc)
print('ham mat mat', test_loss)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 128, 128, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 4,288,454
# Trainable params: 4,288,454
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 32/32 [==============================] - 179s 5s/step - loss: 1.4067 - accuracy: 0.4320
# Epoch 2/30
# 32/32 [==============================] - 175s 6s/step - loss: 1.0303 - accuracy: 0.6053
# Epoch 3/30
# 32/32 [==============================] - 172s 5s/step - loss: 0.8830 - accuracy: 0.6600
# Epoch 4/30
# 32/32 [==============================] - 176s 6s/step - loss: 0.7282 - accuracy: 0.7270
# Epoch 5/30
# 32/32 [==============================] - 171s 5s/step - loss: 0.5708 - accuracy: 0.7900
# Epoch 6/30
# 32/32 [==============================] - 178s 6s/step - loss: 0.4490 - accuracy: 0.8440
# Epoch 7/30
# 32/32 [==============================] - 174s 5s/step - loss: 0.3098 - accuracy: 0.8945
# Epoch 8/30
# 32/32 [==============================] - 172s 5s/step - loss: 0.2156 - accuracy: 0.9315
# Epoch 9/30
# 32/32 [==============================] - 178s 6s/step - loss: 0.1272 - accuracy: 0.9615
# Epoch 10/30
# 32/32 [==============================] - 174s 5s/step - loss: 0.0872 - accuracy: 0.9760
# Epoch 11/30
# 32/32 [==============================] - 175s 5s/step - loss: 0.0502 - accuracy: 0.9870
# Epoch 12/30
# 32/32 [==============================] - 173s 5s/step - loss: 0.0342 - accuracy: 0.9918
# Epoch 13/30
# 32/32 [==============================] - 171s 5s/step - loss: 0.0393 - accuracy: 0.9902
# Epoch 14/30
# 32/32 [==============================] - 173s 5s/step - loss: 0.0190 - accuracy: 0.9975
# Epoch 15/30
# 32/32 [==============================] - 173s 5s/step - loss: 0.0177 - accuracy: 0.9975
# Epoch 16/30
# 32/32 [==============================] - 173s 5s/step - loss: 0.0177 - accuracy: 0.9970
# Epoch 17/30
# 32/32 [==============================] - 174s 5s/step - loss: 0.0163 - accuracy: 0.9973
# Epoch 18/30
# 32/32 [==============================] - 171s 5s/step - loss: 0.0167 - accuracy: 0.9977
# Epoch 19/30
# 32/32 [==============================] - 175s 5s/step - loss: 0.0105 - accuracy: 0.9977
# Epoch 20/30
# 32/32 [==============================] - 177s 5s/step - loss: 0.0090 - accuracy: 0.9980
# Epoch 21/30
# 32/32 [==============================] - 179s 6s/step - loss: 0.0131 - accuracy: 0.9965
# Epoch 22/30
# 32/32 [==============================] - 178s 5s/step - loss: 0.0115 - accuracy: 0.9977
# Epoch 23/30
# 32/32 [==============================] - 177s 6s/step - loss: 0.0105 - accuracy: 0.9970
# Epoch 24/30
# 32/32 [==============================] - 174s 5s/step - loss: 0.0168 - accuracy: 0.9955
# Epoch 25/30
# 32/32 [==============================] - 173s 5s/step - loss: 0.0169 - accuracy: 0.9967
# Epoch 26/30
# 32/32 [==============================] - 173s 5s/step - loss: 0.0919 - accuracy: 0.9675
# Epoch 27/30
# 32/32 [==============================] - 173s 5s/step - loss: 0.0587 - accuracy: 0.9837
# Epoch 28/30
# 32/32 [==============================] - 171s 5s/step - loss: 0.0234 - accuracy: 0.9940
# Epoch 29/30
# 32/32 [==============================] - 173s 5s/step - loss: 0.0162 - accuracy: 0.9958
# Epoch 30/30
# 32/32 [==============================] - 174s 5s/step - loss: 0.0159 - accuracy: 0.9973
# 32/32 [==============================] - 13s 401ms/step - loss: 0.8586 - accuracy: 0.8529
# do chinh xac 0.8528528809547424
# ham mat mat 0.8585807681083679

# %%
import matplotlib.pyplot as plt
accuracy = train.history['accuracy']
loss = train.history['loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'k', label = 'Train accuracy')
plt.plot(epochs, loss, 'b', label = 'Train loss')
plt.legend(['Train accuracy', 'Train loss'])
plt.show()

# %%
model.save('drive/MyDrive/model10flower.h5')

# %%
import numpy as np

file_path = '/content/drive/MyDrive/hoasen.jpg'
test_img  = load_img(file_path, color_mode='rgb', target_size=(128, 128))
img_arr   = img_to_array(test_img).reshape(1, 128, 128, 3)/255

class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])
plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 187ms/step
# Predicted class: Lotus

# %%
file_path = '/content/drive/MyDrive/sunflower.jpg'
test_img  = load_img(file_path, color_mode='rgb', target_size=(128, 128))
img_arr   = img_to_array(test_img).reshape(1, 128, 128, 3)/255

class_pred = np.argmax(model.predict(img_arr))
print("Predicted class:", class_names[class_pred])
plt.imshow(test_img)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# Predicted class: Sunflower
